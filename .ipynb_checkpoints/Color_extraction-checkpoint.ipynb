# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
im = cv2.imread('./index.jpeg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
print(im.shape)
new_r = 100
new_c = int((im.shape[1]/im.shape[0])*new_r)
print(new_c)
img = cv2.resize(im, (new_c, new_r))
print(img.shape)
plt.imshow(img)
# Out:
# (180, 279, 3)
# 155
# (100, 155, 3)

# %%
data = np.reshape(img, (-1,3))
print(data.shape)
print(data.dtype)
# Out:
# (15500, 3)
# uint8

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=8)

# %%
km.fit(data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
centroids = np.array(km.cluster_centers_, dtype=np.dtype(int))
print(centroids.shape)
print(centroids)
# Out:
# (8, 3)
# [[ 24  61  60]
#  [232 235 238]
#  [160 182 193]
#  [113 141 145]
#  [ 19 159 195]
#  [ 10  28  24]
#  [ 76 102  93]
#  [ 15 102 117]]

# %%
freq = np.unique(km.labels_, return_counts = True)
freq
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7], dtype=int32),
#  array([2717, 1917, 2073, 2006, 1142, 2484, 1612, 1549]))

# %%
color_id = freq[0][freq[1].argmax()]

most_dom_color = centroids[color_id]
print(most_dom_color)
# Out:
# [24 61 60]

# %%
display_stamp = np.zeros((20,20,3) , dtype=np.dtype(int))
display_stamp[: ,: ,:] = most_dom_color

plt.imshow(display_stamp)

# %%
freq_ratio = freq[1]/freq[1].sum()
print(freq_ratio)
# Out:
# [0.17529032 0.12367742 0.13374194 0.12941935 0.07367742 0.16025806
#  0.104      0.09993548]

# %%
info = []
for ix in range(freq_ratio.shape[0]):
    item = (centroids[ix],freq_ratio[ix])
    info.append(item)
for cx in info:
    print(cx)
# Out:
# (array([24, 61, 60]), 0.17529032258064517)
# (array([232, 235, 238]), 0.12367741935483871)
# (array([160, 182, 193]), 0.13374193548387098)
# (array([113, 141, 145]), 0.12941935483870967)
# (array([ 19, 159, 195]), 0.07367741935483871)
# (array([10, 28, 24]), 0.16025806451612903)
# (array([ 76, 102,  93]), 0.104)
# (array([ 15, 102, 117]), 0.09993548387096775)

# %%
sorted_values = sorted(info, key=lambda z:z[1], reverse=True)
for ix in sorted_values:
    print (ix)
# Out:
# (array([24, 61, 60]), 0.17529032258064517)
# (array([10, 28, 24]), 0.16025806451612903)
# (array([160, 182, 193]), 0.13374193548387098)
# (array([113, 141, 145]), 0.12941935483870967)
# (array([232, 235, 238]), 0.12367741935483871)
# (array([ 76, 102,  93]), 0.104)
# (array([ 15, 102, 117]), 0.09993548387096775)
# (array([ 19, 159, 195]), 0.07367741935483871)

# %%
print (len(sorted_values))
print (sorted_values[3][0])
# Out:
# 8
# [113 141 145]

# %%
print_matrix = np.ones((10,100,3), dtype=np.dtype(int))
start = 0
for ix in range(len(sorted_values)):
    color = sorted_values[ix][0]
    width = int(sorted_values[ix][1]*print_matrix.shape[1])
    end = start + width
    print_matrix[:, start:end, :] =  color
    start = end
    
plt.imshow(print_matrix)
